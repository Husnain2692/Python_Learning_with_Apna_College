# %% [markdown]
# <a href="https://colab.research.google.com/github/Husnain2692/Python_Learning_with_Apna_College/blob/main/Lec12_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('cars_dataset.csv')
print(data)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0           Audi       A4              43.652               28.007
# 1           Audi       A6              14.379               33.365
# 2         Toyota  Corolla              43.443               11.744
# 3       Mercedes     E300              32.753               19.240
# 4            BMW       X5              74.025               17.063
# ..           ...      ...                 ...                  ...
# 495       Toyota     RAV4              36.619               11.781
# 496        Honda      Fit              60.271               12.590
# 497         Ford    Focus              29.829               26.208
# 498          BMW       M3              46.665               32.639
# 499       Nissan   Patrol              65.863                9.957
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               44.12          3.5          90      120.2
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0           Audi       A4              43.652               28.007
# 1           Audi       A6              14.379               33.365
# 2         Toyota  Corolla              43.443               11.744
# 3       Mercedes     E300              32.753               19.240
# 4            BMW       X5              74.025               17.063
# ..           ...      ...                 ...                  ...
# 495       Toyota     RAV4              36.619               11.781
# 496        Honda      Fit              60.271               12.590
# 497         Ford    Focus              29.829               26.208
# 498          BMW       M3              46.665               32.639
# 499       Nissan   Patrol              65.863                9.957
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               44.12          3.5          90      120.2
# ...

# %%
df['Model']
# Out:
# 0           A4
# 1           A6
# 2      Corolla
# 3         E300
# 4           X5
#         ...
# 495       RAV4
# 496        Fit
# 497      Focus
# 498         M3
# 499     Patrol
# Name: Model, Length: 500, dtype: object

# %%
df['Model'][1]
# Out:
# 'A6'

# %%
df['Model'][499]
# Out:
# 'Patrol'

# %%
df['Manufacturer'][18]
# Out:
# 'Mercedes'

# %%
df.loc[0:5,['Manufacturer','Vehicle_type']]
# Out:
#   Manufacturer Vehicle_type
# 0         Audi    Passenger
# 1         Audi    Passenger
# 2       Toyota    Passenger
# 3     Mercedes          SUV
# 4          BMW          SUV
# 5          BMW          SUV

# %%
df.iloc[0:5,['Manufacturer','Vehicle_Type']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_983/769941766.py in <cell line: 0>()
# ----> 1 df.iloc[0:5,['Manufacturer','Vehicle_Type']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.iloc[0:5,[0,4]]
# Out:
#   Manufacturer Vehicle_type
# 0         Audi    Passenger
# 1         Audi    Passenger
# 2       Toyota    Passenger
# 3     Mercedes          SUV
# 4          BMW          SUV

# %%
df.iloc[0:5,[0,1,3,4]]
# Out:
#   Manufacturer    Model  __year_resale_value Vehicle_type
# 0         Audi       A4               28.007    Passenger
# 1         Audi       A6               33.365    Passenger
# 2       Toyota  Corolla               11.744    Passenger
# 3     Mercedes     E300               19.240          SUV
# 4          BMW       X5               17.063          SUV

# %%
df.iloc[:,0]
# Out:
# 0          Audi
# 1          Audi
# 2        Toyota
# 3      Mercedes
# 4           BMW
#          ...
# 495      Toyota
# 496       Honda
# 497        Ford
# 498         BMW
# 499      Nissan
# Name: Manufacturer, Length: 500, dtype: object

# %%
df.loc[:,['Manufacturer']]
# Out:
#     Manufacturer
# 0           Audi
# 1           Audi
# 2         Toyota
# 3       Mercedes
# 4            BMW
# ..           ...
# 495       Toyota
# 496        Honda
# 497         Ford
# 498          BMW
# 499       Nissan
#
# [500 rows x 1 columns]

# %%
df.Manufacturer=='Audi'
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Manufacturer, Length: 500, dtype: bool

# %%
df.loc[df.Manufacturer=='Audi']
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0           Audi    A4              43.652               28.007    Passenger
# 1           Audi    A6              14.379               33.365    Passenger
# 14          Audi    A3              49.449               42.689          SUV
# 35          Audi    A4              64.849               41.816          SUV
# 76          Audi    Q5              29.827               29.616          SUV
# ..           ...   ...                 ...                  ...          ...
# 475         Audi    Q7               9.268               32.726    Passenger
# 478         Audi    A6              25.807               17.140          SUV
# 482         Audi    Q5              51.747               23.327          SUV
# 487         Audi    Q5              67.304               42.646    Passenger
# 489         Audi    A3              49.841               43.601    Passenger
#
# ...

# %%
df.loc[(df.Manufacturer=='Audi') & (df.Engine_size==2.1)]
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 113         Audi    A4              44.572               25.339    Passenger
# 194         Audi    A4              47.275               17.940    Passenger
# 409         Audi    Q5              50.354               27.539    Passenger
# 482         Audi    Q5              51.747               23.327          SUV
# 489         Audi    A3              49.841               43.601    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 113               32.77          2.1         251      113.8   72.1   201.8
# 194               39.34          2.1         379      115.6   72.5   186.2
# 409               51.91          2.1         217      112.5   69.5   163.9
# 482               47.93          2.1         435       99.0   79.4   178.9
# 489               74.21          2.1         279      120.3   69.4   186.4
#
#      Curb_weight
# 113        2.696
# ...

# %%
df.loc[
    (df.Manufacturer == 'Audi') &
    (df.Engine_size == 2.1) &
    (df.Vehicle_type == 'Passenger')
]
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 113         Audi    A4              44.572               25.339    Passenger
# 194         Audi    A4              47.275               17.940    Passenger
# 409         Audi    Q5              50.354               27.539    Passenger
# 489         Audi    A3              49.841               43.601    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 113               32.77          2.1         251      113.8   72.1   201.8
# 194               39.34          2.1         379      115.6   72.5   186.2
# 409               51.91          2.1         217      112.5   69.5   163.9
# 489               74.21          2.1         279      120.3   69.4   186.4
#
#      Curb_weight
# 113        2.696
# 194        4.572
# 409        3.581
# 489        2.649

# %%
df.loc[
    (df.Manufacturer == 'Audi') &
    (df.Engine_size == 2.1) &
    (df.Vehicle_type == 'Passenger')
]
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0           Audi       A4              43.652               28.007
# 1           Audi       A6              14.379               33.365
# 14          Audi       A3              49.449               42.689
# 22     Chevrolet   Malibu              59.990               27.064
# 30           Kia  Picanto              25.346               13.446
# ..           ...      ...                 ...                  ...
# 475         Audi       Q7               9.268               32.726
# 478         Audi       A6              25.807               17.140
# 482         Audi       Q5              51.747               23.327
# 487         Audi       Q5              67.304               42.646
# 489         Audi       A3              49.841               43.601
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               44.12          3.5          90      120.2
# ...

# %%
df.loc[(df.Manufacturer=='Audi') | (df.Engine_size==2.1)]
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0           Audi       A4              43.652               28.007
# 1           Audi       A6              14.379               33.365
# 14          Audi       A3              49.449               42.689
# 22     Chevrolet   Malibu              59.990               27.064
# 30           Kia  Picanto              25.346               13.446
# ..           ...      ...                 ...                  ...
# 475         Audi       Q7               9.268               32.726
# 478         Audi       A6              25.807               17.140
# 482         Audi       Q5              51.747               23.327
# 487         Audi       Q5              67.304               42.646
# 489         Audi       A3              49.841               43.601
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               44.12          3.5          90      120.2
# ...
