# %% [markdown]
# <a href="https://colab.research.google.com/github/Husnain2692/Python_Learning_with_Apna_College/blob/main/Lec18_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
import seaborn as sns
sns.lineplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#comes from matplotlib
plt.title("Line Plot")
sns.lineplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: title={'center': 'Line Plot'}, xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.title("Scatter Plot")
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: title={'center': 'Scatter Plot'}, xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.title("Bar Plot")
sns.barplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: title={'center': 'Bar Plot'}, xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.title("Bar Plot")
xlabel='total_bill'
ylabel='tip'
sns.barplot(x=xlabel, y=ylabel, data=tips)
# Out:
# <Axes: title={'center': 'Bar Plot'}, xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x='total_bill', y='tip', color='red', marker='o', linestyle='dashed' , data=tips)
plt.title("Line Plot")
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Make the figure 12 inches wide × 7 inches tall
plt.figure(figsize=(12, 7))
sns.lineplot(x='total_bill', y='tip', color='red', marker='o', linestyle='dashed' , data=tips)
plt.title("Line Plot")
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
tips["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.distplot()
# Out:
# /tmp/ipykernel_586/2619735129.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot()
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py:2464: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# <Axes: >

# %%
sns.distplot(tips["total_bill"])
# Out:
# /tmp/ipykernel_586/1984207902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.jointplot(
    data=tips,
    x="total_bill",
    y="tip"
)

# %%
sns.pairplot(tips)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# data=np.random.randint(low=1, high = 100, size = (10,10))
data= np.random.randint(low = 1, high = 100, size = (10,10))

# %%
#print(data)
print(data)
# Out:
# [[69 91 82 72 36 29  8 55 72 54]
#  [82  1 71 56 91 42 21 66  2 37]
#  [48 49 13 95 59 21 44 96 63 24]
#  [86 84 63 40 58 55 13 53 21 66]
#  [36 55 82 20 62 22 92 43 87 20]
#  [13 19 33  4 37 66 69 71 85 15]
#  [ 4 39 29 55 85 25 80 24 28 54]
#  [21 83 43 50 70 50 41 39 27  4]
#  [19 16 38 60 35 10 61 51 33 93]
#  [66 22 78 95 25 47 72 35 95 85]]

# %%
sns.heatmap(data)
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = "spring")
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = "coolwarm")
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = "GnBu")
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = "viridis")
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = "YlOrRd", linecolor = "white", linewidths=3)
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = 'GnBu' , linecolor= 'black', linewidths = 3, annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = 'GnBu' , linecolor= 'black', linewidths = 3, cbar = False)
# Out:
# <Axes: >

# %%
sns.heatmap(data, cmap = 'GnBu' , linecolor= 'black', linewidths = 3, xticklabels=False, yticklabels=False)
# Out:
# <Axes: >

# %%
  tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
correlation = tips[["total_bill", "tip"]].corr()

sns.heatmap(correlation, annot=True, cmap="coolwarm")

plt.show()

# %%
import seaborn as sns

# Select only numerical columns from the tips DataFrame
numerical_tips = tips.select_dtypes(include=['number'])

# Calculate the correlation matrix of the numerical columns
correlation_matrix = numerical_tips.corr()

# Create a heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >
